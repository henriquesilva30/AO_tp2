# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as st

# Configuring matplotlib to display and save images with a white background
plt.rcParams['figure.facecolor'] = 'white'

# Reading the data from the csv file
raw_data = pd.read_csv('View_data_nullZero.csv')
np.set_printoptions(suppress=True)

# Defining some regular bins
# Bin for variation coefiecient
bins_var = [-1, -0.8, -0.6, -0.4, -0.2, 0, 0.2, 0.4, 0.6, 0.8, 1]

# %%
# Bin for values between 0 and 1

# %%
bins_from_zero = [0, 0.2, 0.4, 0.6, 0.8, 1]

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['id_match_competition']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total id_match_competition where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas id_match_competition']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total id_match_competition ']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas id_match_competition
# count                       43823.000000
# mean                          968.521028
# std                          3037.507865
# min                            48.000000
# 25%                           155.000000
# 50%                           221.000000
# 75%                           876.000000
# max                         21843.000000
# mode                          880.000000
#        Nº total id_match_competition
# 48                                109
# 49                                380
# 63                                598
# 66                                616
# 72                                849
# ...                               ...
# 1727                              589
# 1997                               59
# 8613                              574
# 8910                              474
# 21843                             739
#
# [74 rows x 1 columns]
#        Nº total id_match_competition where t1_win
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t1_all_total5_fl_match_win']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t1_all_total5_win where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t1_all_total5_win']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t1_all_total_draw ']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t1_all_total5_win
# count                    43823.000000
# mean                         1.629441
# std                          1.216467
# min                         -1.000000
# 25%                          1.000000
# 50%                          2.000000
# 75%                          2.000000
# max                          5.000000
# mode                         1.000000
#     Nº total de t1_all_total_draw
# -1                              12
#  0                            8658
#  1                           13023
#  2                           11895
#  3                            6916
#  4                            2737
#  5                             582
#     Nº total t1_all_total5_win where t1_win
# -1                                        5
#  0                                     3142
#  1                                     4989
#  2                                     5160
#  3                                     3315
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t1_all_total5_fl_match_draw']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t1_all_total5_draw where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t1_all_total5_draw']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t1_all_total5_draw ']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t1_all_total5_draw
# count                     43823.000000
# mean                          1.211168
# std                           1.004665
# min                          -1.000000
# 25%                           0.000000
# 50%                           1.000000
# 75%                           2.000000
# max                           5.000000
# mode                          1.000000
#     Nº total de t1_all_total5_draw
# -1                               20
#  0                            11912
#  1                            16274
#  2                            10876
#  3                             3950
#  4                              734
#  5                               57
#     Nº total t1_all_total5_draw where t1_win
# -1                                         8
#  0                                      5040
#  1                                      6977
#  2                                      4485
#  3                                      1645
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t1_all_total5_fl_match_lost']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t1_all_total5_lost where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t1_all_total5_lost']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t1_all_total5_lost ']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t1_all_total5_lost
# count                     43823.000000
# mean                          1.670447
# std                           1.217528
# min                          -1.000000
# 25%                           1.000000
# 50%                           2.000000
# 75%                           2.000000
# max                           5.000000
# mode                          1.000000
#     Nº total de t1_all_total5_lost
# -1                               14
#  0                             8322
#  1                            12549
#  2                            12091
#  3                             7437
#  4                             2874
#  5                              536
#     Nº total t1_all_total5_lost where t1_win
# -1                                         5
#  0                                      4101
#  1                                      5644
#  2                                      4887
#  3                                      2767
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t1_all_total10_fl_match_win']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t1_all_total10_win where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t1_all_total10_win']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t1_all_total10_win ']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t1_all_total10_win
# count                     43823.000000
# mean                          2.989709
# std                           2.030687
# min                          -1.000000
# 25%                           1.000000
# 50%                           3.000000
# 75%                           4.000000
# max                          10.000000
# mode                          2.000000
#      Nº total de t1_all_total10_win
# -1                                12
#  0                              5008
#  1                              6432
#  2                              7974
#  3                              7815
#  4                              6683
#  5                              4580
#  6                              2917
#  7                              1473
#  8                               646
#  9                               238
#  10                               45
#      Nº total t1_all_total10_win where t1_win
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t1_all_total10_fl_match_draw']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t1_all_total10_draw where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t1_all_total10_draw']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t1_all_total10_draw ']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t1_all_total10_draw
# count                      43823.000000
# mean                           2.214727
# std                            1.532358
# min                           -1.000000
# 25%                            1.000000
# 50%                            2.000000
# 75%                            3.000000
# max                            9.000000
# mode                           2.000000
#     Nº total de t1_all_total10_draw
# -1                                20
#  0                              6339
#  1                              9119
#  2                             10566
#  3                              8871
#  4                              5522
#  5                              2401
#  6                               803
#  7                               156
#  8                                25
#  9                                 1
#     Nº total t1_all_total10_draw where t1_win
# -1                                          8
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t1_all_total10_fl_match_lost']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t1_all_total10_lost where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t1_all_total10_lost']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t1_all_total10_lost ']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t1_all_total10_lost
# count                      43823.000000
# mean                           3.018598
# std                            2.002405
# min                           -1.000000
# 25%                            1.000000
# 50%                            3.000000
# 75%                            4.000000
# max                           10.000000
# mode                           3.000000
#      Nº total de t1_all_total10_lost
# -1                                 14
#  0                               5035
#  1                               6292
#  2                               7357
#  3                               7788
#  4                               6953
#  5                               5196
#  6                               3063
#  7                               1420
#  8                                554
#  9                                124
#  10                                27
#      Nº total t1_all_total10_lost where t1_win
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t2_all_total5_fl_match_win']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t2_all_total5_win where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t2_all_total5_win']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t2_all_total5_win']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t2_all_total5_win
# count                    43823.000000
# mean                         1.678981
# std                          1.226615
# min                         -1.000000
# 25%                          1.000000
# 50%                          2.000000
# 75%                          2.000000
# max                          5.000000
# mode                         1.000000
#     Nº total de t2_all_total5_win
# -1                             13
#  0                           8203
#  1                          12725
#  2                          11997
#  3                           7298
#  4                           2957
#  5                            630
#     Nº total t2_all_total5_win where t1_win
# -1                                        7
#  0                                     3860
#  1                                     5768
#  2                                     5073
#  3                                     2695
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t2_all_total5_fl_match_draw']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t2_all_total5_draw where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t2_all_total5_draw']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t2_all_total5_draw']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t2_all_total5_draw
# count                     43823.000000
# mean                          1.210460
# std                           1.008384
# min                          -1.000000
# 25%                           0.000000
# 50%                           1.000000
# 75%                           2.000000
# max                           5.000000
# mode                          1.000000
#     Nº total de t2_all_total5_draw
# -1                              22
#  0                           12032
#  1                           16108
#  2                           10873
#  3                            3991
#  4                             744
#  5                              53
#     Nº total t2_all_total5_draw where t1_win
# -1                                         8
#  0                                      5026
#  1                                      6836
#  2                                      4595
#  3                                      1677
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t2_all_total5_fl_match_lost']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t2_all_total5_lost where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t2_all_total5_lost']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t2_all_total5_lost']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t2_all_total5_lost
# count                     43823.000000
# mean                          1.621500
# std                           1.209953
# min                          -1.000000
# 25%                           1.000000
# 50%                           2.000000
# 75%                           2.000000
# max                           5.000000
# mode                          1.000000
#     Nº total de t2_all_total5_lost
# -1                              14
#  0                            8926
#  1                           12566
#  2                           12044
#  3                            7155
#  4                            2636
#  5                             482
#     Nº total t2_all_total5_lost where t1_win
# -1                                         4
#  0                                      3164
#  1                                      5033
#  2                                      5235
#  3                                      3381
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t2_all_total10_fl_match_win']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t2_all_total10_win where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t2_all_total10_win']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t2_all_total10_win']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t2_all_total10_win
# count                     43823.000000
# mean                          3.042329
# std                           2.038852
# min                          -1.000000
# 25%                           1.000000
# 50%                           3.000000
# 75%                           4.000000
# max                          10.000000
# mode                          3.000000
#      Nº total de t2_all_total10_win
# -1                               13
#  0                             4730
#  1                             6420
#  2                             7731
#  3                             7957
#  4                             6647
#  5                             4848
#  6                             2919
#  7                             1566
#  8                              700
#  9                              240
#  10                              52
#      Nº total t2_all_total10_win where t1_win
# -1                                          7
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t2_all_total10_fl_match_draw']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t2_all_total10_draw where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t2_all_total10_draw']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t2_all_total10_draw']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t2_all_total10_draw
# count                      43823.000000
# mean                           2.209707
# std                            1.536042
# min                           -1.000000
# 25%                            1.000000
# 50%                            2.000000
# 75%                            3.000000
# max                            9.000000
# mode                           2.000000
#     Nº total de t2_all_total10_draw
# -1                               22
#  0                             6407
#  1                             9233
#  2                            10391
#  3                             8830
#  4                             5491
#  5                             2488
#  6                              802
#  7                              138
#  8                               18
#  9                                3
#     Nº total t2_all_total10_draw where t1_win
# -1                                          8
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t2_all_total10_fl_match_lost']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t2_all_total10_lost where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t2_all_total10_lost']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t2_all_total10_lost']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t2_all_total10_lost
# count                       43823.00000
# mean                            2.97410
# std                             1.99832
# min                            -1.00000
# 25%                             1.00000
# 50%                             3.00000
# 75%                             4.00000
# max                            10.00000
# mode                            3.00000
#      Nº total de t2_all_total10_lost
# -1                                14
#  0                              5304
#  1                              6277
#  2                              7521
#  3                              7751
#  4                              6874
#  5                              5116
#  6                              2898
#  7                              1413
#  8                               494
#  9                               141
#  10                               20
#      Nº total t2_all_total10_lost where t1_win
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t1_home_total5_fl_match_win']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t1_home_total5_win where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t1_home_total5_win']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t1_home_total5_win']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t1_home_total5_win
# count                     43823.000000
# mean                          1.712913
# std                           1.311012
# min                          -1.000000
# 25%                           1.000000
# 50%                           2.000000
# 75%                           3.000000
# max                           5.000000
# mode                          1.000000
#     Nº total de t1_home_total5_win
# -1                               7
#  0                            9232
#  1                           11639
#  2                           10826
#  3                            7650
#  4                            3514
#  5                             955
#     Nº total t1_home_total5_win where t1_win
# -1                                         1
#  0                                      3470
#  1                                      4428
#  2                                      4580
#  3                                      3622
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t1_home_total5_fl_match_draw']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t1_home_total5_draw where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t1_home_total5_draw']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t1_home_total5_draw']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t1_home_total5_draw
# count                      43823.000000
# mean                           1.085229
# std                            0.994516
# min                           -1.000000
# 25%                            0.000000
# 50%                            1.000000
# 75%                            2.000000
# max                            5.000000
# mode                           1.000000
#     Nº total de t1_home_total5_draw
# -1                                9
#  0                            14568
#  1                            15573
#  2                             9703
#  3                             3334
#  4                              594
#  5                               42
#     Nº total t1_home_total5_draw where t1_win
# -1                                          2
#  0                                       6305
#  1                                       6575
#  2                                       4042
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t1_home_total5_fl_match_lost']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t1_home_total5_lost where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t1_home_total5_lost']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t1_home_total5_lost']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t1_home_total5_lost
# count                      43823.000000
# mean                           1.235835
# std                            1.129387
# min                           -1.000000
# 25%                            0.000000
# 50%                            1.000000
# 75%                            2.000000
# max                            5.000000
# mode                           0.000000
#     Nº total de t1_home_total5_lost
# -1                                4
#  0                            13907
#  1                            13766
#  2                             9816
#  3                             4758
#  4                             1370
#  5                              202
#     Nº total t1_home_total5_lost where t1_win
# -1                                          1
#  0                                       6603
#  1                                       5975
#  2                                       3772
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t1_home_total10_fl_match_win']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t1_home_total10_win where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t1_home_total10_win']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t1_home_total10_win']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t1_home_total10_win
# count                      43823.000000
# mean                           2.773042
# std                            2.163719
# min                           -1.000000
# 25%                            1.000000
# 50%                            2.000000
# 75%                            4.000000
# max                           10.000000
# mode                           2.000000
#      Nº total de t1_home_total10_win
# -1                                 7
#  0                              7328
#  1                              7382
#  2                              7427
#  3                              6669
#  4                              5450
#  5                              4030
#  6                              2873
#  7                              1562
#  8                               765
#  9                               255
#  10                               75
#      Nº total t1_home_total10_win where t1_win
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t1_home_total10_fl_match_draw']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t1_home_total10_draw where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t1_home_total10_draw']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t1_home_total10_draw']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t1_home_total10_draw
# count                       43823.000000
# mean                            1.765420
# std                             1.501711
# min                            -1.000000
# 25%                             1.000000
# 50%                             2.000000
# 75%                             3.000000
# max                             9.000000
# mode                            1.000000
#     Nº total de t1_home_total10_draw
# -1                                 9
#  0                             10613
#  1                             10756
#  2                              9744
#  3                              6749
#  4                              3697
#  5                              1597
#  6                               514
#  7                               127
#  8                                15
#  9                                 2
#     Nº total t1_home_total10_draw where t1_win
# -1                                           2
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t1_home_total10_fl_match_lost']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t1_home_total10_lost where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t1_home_total10_lost']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t1_home_total10_lost']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t1_home_total10_lost
# count                       43823.000000
# mean                            2.001985
# std                             1.770186
# min                            -1.000000
# 25%                             1.000000
# 50%                             2.000000
# 75%                             3.000000
# max                            10.000000
# mode                            0.000000
#      Nº total de t1_home_total10_lost
# -1                                  4
#  0                              10648
#  1                               9741
#  2                               8274
#  3                               6380
#  4                               4251
#  5                               2638
#  6                               1289
#  7                                452
#  8                                108
#  9                                 28
#  10                                10
#      Nº total t1_home_total10_lost where t1_win
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t2_away_total5_fl_match_win']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t2_away_total5_win where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t2_away_total5_win']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t2_away_total5_win']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t2_away_total5_win
# count                     43823.000000
# mean                          1.246058
# std                           1.140547
# min                          -1.000000
# 25%                           0.000000
# 50%                           1.000000
# 75%                           2.000000
# max                           5.000000
# mode                          1.000000
#     Nº total de t2_away_total5_win
# -1                               6
#  0                           13749
#  1                           13906
#  2                            9810
#  3                            4581
#  4                            1512
#  5                             259
#     Nº total t2_away_total5_win where t1_win
# -1                                         1
#  0                                      6414
#  1                                      6084
#  2                                      3926
#  3                                      1573
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t2_away_total5_fl_match_draw']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t2_away_total5_draw where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t2_away_total5_draw']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t2_away_total5_draw']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t2_away_total5_draw
# count                      43823.000000
# mean                           1.086507
# std                            1.001061
# min                           -1.000000
# 25%                            0.000000
# 50%                            1.000000
# 75%                            2.000000
# max                            5.000000
# mode                           1.000000
#     Nº total de t2_away_total5_draw
# -1                                9
#  0                            14600
#  1                            15616
#  2                             9532
#  3                             3364
#  4                              659
#  5                               43
#     Nº total t2_away_total5_draw where t1_win
# -1                                          2
#  0                                       6289
#  1                                       6554
#  2                                       3963
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t2_away_total5_fl_match_lost']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t2_away_total5_lost where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t2_away_total5_lost']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t2_away_total5_lost']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t2_away_total5_lost
# count                      43823.000000
# mean                           1.702668
# std                            1.294816
# min                           -1.000000
# 25%                            1.000000
# 50%                            2.000000
# 75%                            3.000000
# max                            5.000000
# mode                           2.000000
#     Nº total de t2_away_total5_lost
# -1                                5
#  0                             9422
#  1                            11154
#  2                            11221
#  3                             7834
#  4                             3412
#  5                              775
#     Nº total t2_away_total5_lost where t1_win
# -1                                          1
#  0                                       3395
#  1                                       4416
#  2                                       4889
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t2_away_total10_fl_match_win']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t2_away_total10_win where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t2_away_total10_win']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t2_away_total10_win']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t2_away_total10_win
# count                      43823.000000
# mean                           2.020788
# std                            1.798597
# min                           -1.000000
# 25%                            1.000000
# 50%                            2.000000
# 75%                            3.000000
# max                           10.000000
# mode                           0.000000
#      Nº total de t2_away_total10_win
# -1                                 6
#  0                             10498
#  1                              9685
#  2                              8458
#  3                              6524
#  4                              4160
#  5                              2424
#  6                              1225
#  7                               559
#  8                               207
#  9                                59
#  10                               18
#      Nº total t2_away_total10_win where t1_win
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t2_away_total10_fl_match_draw']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t2_away_total10_draw where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t2_away_total10_draw']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t2_away_total10_draw']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t2_away_total10_draw
# count                       43823.000000
# mean                            1.768364
# std                             1.505620
# min                            -1.000000
# 25%                             1.000000
# 50%                             2.000000
# 75%                             3.000000
# max                             9.000000
# mode                            0.000000
#     Nº total de t2_away_total10_draw
# -1                                 9
#  0                             10750
#  1                             10581
#  2                              9548
#  3                              6946
#  4                              3778
#  5                              1529
#  6                               559
#  7                               108
#  8                                13
#  9                                 2
#     Nº total t2_away_total10_draw where t1_win
# -1                                           2
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t2_away_total10_fl_match_lost']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t2_away_total10_lost where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t2_away_total10_lost']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t2_away_total10_lost']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t2_away_total10_lost
# count                       43823.000000
# mean                            2.753531
# std                             2.125962
# min                            -1.000000
# 25%                             1.000000
# 50%                             3.000000
# 75%                             4.000000
# max                            10.000000
# mode                            0.000000
#      Nº total de t2_away_total10_lost
# -1                                  5
#  0                               7570
#  1                               7304
#  2                               7015
#  3                               6515
#  4                               5803
#  5                               4464
#  6                               2812
#  7                               1538
#  8                                577
#  9                                192
#  10                                28
#      Nº total t2_away_total10_lost where t1_win
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t1_h2h_total5_fl_match_win']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t1_h2h_total5_win where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t1_h2h_total5_win']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t1_h2h_total5_win']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t1_h2h_total5_win
# count                    43823.000000
# mean                         1.331835
# std                          1.249549
# min                          0.000000
# 25%                          0.000000
# 50%                          1.000000
# 75%                          2.000000
# max                          5.000000
# mode                         0.000000
#    Nº total de t1_h2h_total5_win
# 0                          14099
# 1                          12447
# 2                           9242
# 3                           5267
# 4                           2207
# 5                            561
#    Nº total t1_h2h_total5_win where t1_win
# 0                                     5235
# 1                                     4775
# 2                                     4119
# 3                                     2646
# 4                                     1309
# 5                                      399
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t1_h2h_total5_fl_match_draw']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t1_h2h_total5_fl_match_draw where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t1_h2h_total5_fl_match_draw']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t1_h2h_total5_fl_match_draw']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t1_h2h_total5_fl_match_draw
# count                              43823.000000
# mean                                   0.974990
# std                                    0.992356
# min                                    0.000000
# 25%                                    0.000000
# 50%                                    1.000000
# 75%                                    2.000000
# max                                    5.000000
# mode                                   0.000000
#    Nº total de t1_h2h_total5_fl_match_draw
# 0                                    17269
# 1                                    14549
# 2                                     8487
# 3                                     2920
# 4                                      546
# 5                                       52
#    Nº total t1_h2h_total5_fl_match_draw where t1_win
# 0                                               7397
# 1                                               6107
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t1_h2h_total5_fl_match_lost']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t1_h2h_total5_fl_match_lost where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t1_h2h_total5_fl_match_lost']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t1_h2h_total5_fl_match_lost']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t1_h2h_total5_fl_match_lost
# count                              43823.000000
# mean                                   1.385277
# std                                    1.261386
# min                                    0.000000
# 25%                                    0.000000
# 50%                                    1.000000
# 75%                                    2.000000
# max                                    5.000000
# mode                                   0.000000
#    Nº total de t1_h2h_total5_fl_match_lost
# 0                                    13187
# 1                                    12714
# 2                                     9460
# 3                                     5425
# 4                                     2387
# 5                                      650
#    Nº total t1_h2h_total5_fl_match_lost where t1_win
# 0                                               6270
# 1                                               5733
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t1_h2h_total10_fl_match_win']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t1_h2h_total10_fl_match_win where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t1_h2h_total10_fl_match_win']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t1_h2h_total10_fl_match_win']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t1_h2h_total10_fl_match_win
# count                              43823.000000
# mean                                   2.131324
# std                                    2.053677
# min                                    0.000000
# 25%                                    0.000000
# 50%                                    2.000000
# 75%                                    3.000000
# max                                   10.000000
# mode                                   0.000000
#     Nº total de t1_h2h_total10_fl_match_win
# 0                                     11836
# 1                                      9006
# 2                                      7185
# 3                                      5562
# 4                                      4074
# 5                                      2691
# 6                                      1705
# 7                                      1038
# 8                                       489
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t1_h2h_total10_fl_match_draw']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t1_h2h_total10_fl_match_draw where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t1_h2h_total10_fl_match_draw']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t1_h2h_total10_fl_match_draw']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t1_h2h_total10_fl_match_draw
# count                               43823.000000
# mean                                    1.528741
# std                                     1.472533
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     1.000000
# 75%                                     2.000000
# max                                     8.000000
# mode                                    0.000000
#    Nº total de t1_h2h_total10_fl_match_draw
# 0                                     13787
# 1                                     10917
# 2                                      8486
# 3                                      5846
# 4                                      3017
# 5                                      1254
# 6                                       401
# 7                                        97
# 8                                        18
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t1_h2h_total10_fl_match_lost']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t1_h2h_total10_fl_match_lost where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t1_h2h_total10_fl_match_lost']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t1_h2h_total10_fl_match_lost']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t1_h2h_total10_fl_match_lost
# count                               43823.000000
# mean                                    2.184766
# std                                     2.059911
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     2.000000
# 75%                                     3.000000
# max                                    10.000000
# mode                                    0.000000
#     Nº total de t1_h2h_total10_fl_match_lost
# 0                                      11062
# 1                                       9312
# 2                                       7338
# 3                                       5574
# 4                                       4151
# 5                                       2796
# 6                                       1769
# 7                                       1052
# 8                                        503
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t2_h2h_total5_fl_match_win']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t2_h2h_total5_fl_match_win where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t2_h2h_total5_fl_match_win']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t2_h2h_total5_fl_match_win']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t2_h2h_total5_fl_match_win
# count                             43823.000000
# mean                                  1.385277
# std                                   1.261386
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   1.000000
# 75%                                   2.000000
# max                                   5.000000
# mode                                  0.000000
#    Nº total de t2_h2h_total5_fl_match_win
# 0                                   13187
# 1                                   12714
# 2                                    9460
# 3                                    5425
# 4                                    2387
# 5                                     650
#    Nº total t2_h2h_total5_fl_match_win where t1_win
# 0                                              6270
# 1                                              5733
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t2_h2h_total5_fl_match_draw']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t2_h2h_total5_fl_match_draw where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t2_h2h_total5_fl_match_draw']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t2_h2h_total5_fl_match_draw']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t2_h2h_total5_fl_match_draw
# count                              43823.000000
# mean                                   0.974990
# std                                    0.992356
# min                                    0.000000
# 25%                                    0.000000
# 50%                                    1.000000
# 75%                                    2.000000
# max                                    5.000000
# mode                                   0.000000
#    Nº total de t2_h2h_total5_fl_match_draw
# 0                                    17269
# 1                                    14549
# 2                                     8487
# 3                                     2920
# 4                                      546
# 5                                       52
#    Nº total t2_h2h_total5_fl_match_draw where t1_win
# 0                                               7397
# 1                                               6107
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t2_h2h_total5_fl_match_lost']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t2_h2h_total5_fl_match_lost where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t2_h2h_total5_fl_match_lost']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t2_h2h_total5_fl_match_lost']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t2_h2h_total5_fl_match_lost
# count                              43823.000000
# mean                                   1.331835
# std                                    1.249549
# min                                    0.000000
# 25%                                    0.000000
# 50%                                    1.000000
# 75%                                    2.000000
# max                                    5.000000
# mode                                   0.000000
#    Nº total de t2_h2h_total5_fl_match_lost
# 0                                    14099
# 1                                    12447
# 2                                     9242
# 3                                     5267
# 4                                     2207
# 5                                      561
#    Nº total t2_h2h_total5_fl_match_lost where t1_win
# 0                                               5235
# 1                                               4775
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t2_h2h_total10_fl_match_win']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t2_h2h_total10_fl_match_win where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t2_h2h_total10_fl_match_win']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t2_h2h_total10_fl_match_win']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t2_h2h_total10_fl_match_win
# count                              43823.000000
# mean                                   2.184766
# std                                    2.059911
# min                                    0.000000
# 25%                                    0.000000
# 50%                                    2.000000
# 75%                                    3.000000
# max                                   10.000000
# mode                                   0.000000
#     Nº total de t2_h2h_total10_fl_match_win
# 0                                     11062
# 1                                      9312
# 2                                      7338
# 3                                      5574
# 4                                      4151
# 5                                      2796
# 6                                      1769
# 7                                      1052
# 8                                       503
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t2_h2h_total10_fl_match_draw']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t2_h2h_total10_fl_match_draw where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t2_h2h_total10_fl_match_draw']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t2_h2h_total10_fl_match_draw']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t2_h2h_total10_fl_match_draw
# count                               43823.000000
# mean                                    1.528741
# std                                     1.472533
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     1.000000
# 75%                                     2.000000
# max                                     8.000000
# mode                                    0.000000
#    Nº total de t2_h2h_total10_fl_match_draw
# 0                                     13787
# 1                                     10917
# 2                                      8486
# 3                                      5846
# 4                                      3017
# 5                                      1254
# 6                                       401
# 7                                        97
# 8                                        18
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t2_h2h_total10_fl_match_lost']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t2_h2h_total10_fl_match_lost where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t2_h2h_total10_fl_match_lost']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t2_h2h_total10_fl_match_lost']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t2_h2h_total10_fl_match_lost
# count                               43823.000000
# mean                                    2.131324
# std                                     2.053677
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     2.000000
# 75%                                     3.000000
# max                                    10.000000
# mode                                    0.000000
#     Nº total de t2_h2h_total10_fl_match_lost
# 0                                      11836
# 1                                       9006
# 2                                       7185
# 3                                       5562
# 4                                       4074
# 5                                       2691
# 6                                       1705
# 7                                       1038
# 8                                        489
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t1_h2h_home_total5_fl_match_win']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t1_h2h_home_total5_fl_match_win where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t1_h2h_home_total5_fl_match_win']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t1_h2h_home_total5_fl_match_win']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t1_h2h_home_total5_fl_match_win
# count                                  43823.000000
# mean                                       1.226730
# std                                        1.291017
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        1.000000
# 75%                                        2.000000
# max                                        5.000000
# mode                                       0.000000
#    Nº total de t1_h2h_home_total5_fl_match_win
# 0                                        16892
# 1                                        11491
# 2                                         7742
# 3                                         4716
# 4                                         2274
# 5                                          708
#    Nº total t1_h2h_home_total5_fl_match_win where t1_win
# 0                                               6564
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t1_h2h_home_total5_fl_match_draw']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t1_h2h_home_total5_fl_match_draw where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t1_h2h_home_total5_fl_match_draw']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t1_h2h_home_total5_fl_match_draw']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t1_h2h_home_total5_fl_match_draw
# count                                   43823.000000
# mean                                        0.721334
# std                                         0.900445
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         0.000000
# 75%                                         1.000000
# max                                         5.000000
# mode                                        0.000000
#    Nº total de t1_h2h_home_total5_fl_match_draw
# 0                                         22767
# 1                                         12939
# 2                                          6021
# 3                                          1780
# 4                                           290
# 5                                            26
#    Nº total t1_h2h_home_total5_fl_match_draw where t1_win
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t1_h2h_home_total5_fl_match_lost']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t1_h2h_home_total5_fl_match_lost where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t1_h2h_home_total5_fl_match_lost']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t1_h2h_home_total5_fl_match_lost']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t1_h2h_home_total5_fl_match_lost
# count                                   43823.000000
# mean                                        0.817037
# std                                         1.056427
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         0.000000
# 75%                                         1.000000
# max                                         5.000000
# mode                                        0.000000
#    Nº total de t1_h2h_home_total5_fl_match_lost
# 0                                         22537
# 1                                         11850
# 2                                          5712
# 3                                          2582
# 4                                           925
# 5                                           217
#    Nº total t1_h2h_home_total5_fl_match_lost where t1_win
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t1_h2h_home_total10_fl_match_win']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t1_h2h_home_total10_fl_match_win where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t1_h2h_home_total10_fl_match_win']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t1_h2h_home_total10_fl_match_win']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t1_h2h_home_total10_fl_match_win
# count                                   43823.000000
# mean                                        1.489218
# std                                         1.686693
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         1.000000
# 75%                                         2.000000
# max                                        10.000000
# mode                                        0.000000
#     Nº total de t1_h2h_home_total10_fl_match_win
# 0                                          16354
# 1                                          10522
# 2                                           6884
# 3                                           4451
# 4                                           2743
# 5                                           1518
# 6                                            740
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t1_h2h_home_total10_fl_match_draw']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t1_h2h_home_total10_fl_match_draw where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t1_h2h_home_total10_fl_match_draw']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t1_h2h_home_total10_fl_match_draw']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t1_h2h_home_total10_fl_match_draw
# count                                    43823.000000
# mean                                         0.871415
# std                                          1.096466
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          1.000000
# 75%                                          1.000000
# max                                          8.000000
# mode                                         0.000000
#    Nº total de t1_h2h_home_total10_fl_match_draw
# 0                                          21605
# 1                                          11918
# 2                                           6318
# 3                                           2737
# 4                                            894
# 5                                            281
# 6                                             50
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t1_h2h_home_total10_fl_match_lost']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t1_h2h_home_total10_fl_match_lost where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t1_h2h_home_total10_fl_match_lost']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t1_h2h_home_total10_fl_match_lost']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t1_h2h_home_total10_fl_match_lost
# count                                    43823.000000
# mean                                         0.989229
# std                                          1.335378
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          1.000000
# 75%                                          2.000000
# max                                         10.000000
# mode                                         0.000000
#     Nº total de t1_h2h_home_total10_fl_match_lost
# 0                                           21648
# 1                                           11025
# 2                                            5659
# 3                                            2921
# 4                                            1384
# 5                                             669
# 6                                             336
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t2_h2h_away_total5_fl_match_win']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t2_h2h_away_total5_fl_match_win where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t2_h2h_away_total5_fl_match_win']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t2_h2h_away_total5_fl_match_win']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t2_h2h_away_total5_fl_match_win
# count                                  43823.000000
# mean                                       0.817037
# std                                        1.056427
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        1.000000
# max                                        5.000000
# mode                                       0.000000
#    Nº total de t2_h2h_away_total5_fl_match_win
# 0                                        22537
# 1                                        11850
# 2                                         5712
# 3                                         2582
# 4                                          925
# 5                                          217
#    Nº total t2_h2h_away_total5_fl_match_win where t1_win
# 0                                              10248
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t2_h2h_away_total5_fl_match_draw']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t2_h2h_away_total5_fl_match_draw where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t2_h2h_away_total5_fl_match_draw']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t2_h2h_away_total5_fl_match_draw']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t2_h2h_away_total5_fl_match_draw
# count                                   43823.000000
# mean                                        0.721334
# std                                         0.900445
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         0.000000
# 75%                                         1.000000
# max                                         5.000000
# mode                                        0.000000
#    Nº total de t2_h2h_away_total5_fl_match_draw
# 0                                         22767
# 1                                         12939
# 2                                          6021
# 3                                          1780
# 4                                           290
# 5                                            26
#    Nº total t2_h2h_away_total5_fl_match_draw where t1_win
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t2_h2h_away_total5_fl_match_lost']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t2_h2h_away_total5_fl_match_lost where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t2_h2h_away_total5_fl_match_lost']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t2_h2h_away_total5_fl_match_lost']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t2_h2h_away_total5_fl_match_lost
# count                                   43823.000000
# mean                                        1.226730
# std                                         1.291017
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         1.000000
# 75%                                         2.000000
# max                                         5.000000
# mode                                        0.000000
#    Nº total de t2_h2h_away_total5_fl_match_lost
# 0                                         16892
# 1                                         11491
# 2                                          7742
# 3                                          4716
# 4                                          2274
# 5                                           708
#    Nº total t2_h2h_away_total5_fl_match_lost where t1_win
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t2_h2h_away_total10_fl_match_win']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t2_h2h_away_total10_fl_match_win where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t2_h2h_away_total10_fl_match_win']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t2_h2h_away_total10_fl_match_win']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t2_h2h_away_total10_fl_match_win
# count                                   43823.000000
# mean                                        0.989229
# std                                         1.335378
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         1.000000
# 75%                                         2.000000
# max                                        10.000000
# mode                                        0.000000
#     Nº total de t2_h2h_away_total10_fl_match_win
# 0                                          21648
# 1                                          11025
# 2                                           5659
# 3                                           2921
# 4                                           1384
# 5                                            669
# 6                                            336
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t2_h2h_away_total10_fl_match_draw']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t2_h2h_away_total10_fl_match_draw where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t2_h2h_away_total10_fl_match_draw']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t2_h2h_away_total10_fl_match_draw']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t2_h2h_away_total10_fl_match_draw
# count                                    43823.000000
# mean                                         0.871415
# std                                          1.096466
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          1.000000
# 75%                                          1.000000
# max                                          8.000000
# mode                                         0.000000
#    Nº total de t2_h2h_away_total10_fl_match_draw
# 0                                          21605
# 1                                          11918
# 2                                           6318
# 3                                           2737
# 4                                            894
# 5                                            281
# 6                                             50
# ...

# %%
# Dados dos resultados do jogos de 2014-2022
curColumn = raw_data['t2_h2h_away_total10_fl_match_lost']

fPorComp = curColumn[raw_data['t1_fl_match_win'] == 1]
vitoriasPorComp = pd.DataFrame(fPorComp.value_counts().sort_index())
vitoriasPorComp.columns = ['Nº total t2_h2h_away_total10_fl_match_lost where t1_win']

colSummary = curColumn.describe()
colSummary.loc['mode'] = curColumn.mode().tolist()[0]
dfSummary = pd.DataFrame(colSummary)
dfSummary.columns = ['Estatisticas t2_h2h_away_total10_fl_match_lost']
display(dfSummary)

totalPerAtrr = pd.DataFrame(curColumn.value_counts().sort_index())
totalPerAtrr.columns = ['Nº total de t2_h2h_away_total10_fl_match_lost']
display(totalPerAtrr)
display(vitoriasPorComp)

curColumn.value_counts().sort_index().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    radius=2,
    pctdistance=1.1,
    labeldistance=0.5
)
# Out:
#        Estatisticas t2_h2h_away_total10_fl_match_lost
# count                                    43823.000000
# mean                                         1.489218
# std                                          1.686693
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          1.000000
# 75%                                          2.000000
# max                                         10.000000
# mode                                         0.000000
#     Nº total de t2_h2h_away_total10_fl_match_lost
# 0                                           16354
# 1                                           10522
# 2                                            6884
# 3                                            4451
# 4                                            2743
# 5                                            1518
# 6                                             740
# ...

# %%
# Configuring the matplotlib figure size and title
fig, ax = plt.subplots(figsize=(30,30))
ax.set_title('Correlation between variables in dataset')

# Excluding the categorical columns from dataframe
filtered_data = raw_data.drop(["id_match_api", "dt_match", "id_match_competition", "id_match_competition", "cd_season","cd_round","id_match_status"], axis=1)
heatmap = sns.heatmap(filtered_data.corr(), vmin=-1, vmax=1, annot=True, ax=ax, cmap="icefire")

# Saving the image to a file
plt.savefig('correlation_matrix_null_zero.png', bbox_inches="tight")

# %%
raw_data.head()
# Out:
#    id_match_api             dt_match  id_match_status  id_match_competition  \
# 0       1174816  2014-04-27 08:00:00                3                  8910
# 1       1174817  2014-05-03 06:00:00                3                  8910
# 2       1227501  2014-05-03 06:00:00                3                  8910
# 3       1227502  2014-05-03 06:00:00                3                  8910
# 4       1238394  2014-05-03 08:00:00                3                  8910
#
#             cd_season  cd_round  t1_all_total5_fl_match_win  \
# 0  kr_k-league_1_2020        10                           0
# 1  kr_k-league_1_2020        11                           0
# 2  kr_k-league_1_2020        11                           0
# 3  kr_k-league_1_2020        11                           0
# 4  kr_k-league_1_2020        11                           0
#
#    t1_all_total5_fl_match_draw  t1_all_total5_fl_match_lost  \
# 0                            0                            0
# ...

# %%
import seaborn as sn
m=raw_data.corr()
sn.heatmap(m, annot=True)
# Out:
# <AxesSubplot:>

# %%
sn.set_theme(style="dark")
g=sn.pairplot(raw_data, hue="t1_fl_match_win")
g.savefig("scatterplot_matrix.png")
# Out:
# KeyboardInterrupt
# Error in callback <function flush_figures at 0x000001702F75C3A0> (for post_execute):
# KeyboardInterrupt

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=38864aa7-bbc4-4818-a3f0-8a94ab3f9be2' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>

# %%
sns.pairplot(raw_data[['t1_all_total5_fl_match_lost', 't1_all_total5_fl_match_win', 't1_all_total5_fl_match_draw', 't1_all_total10_fl_match_lost', 't1_all_total10_fl_match_win','t1_all_total10_fl_match_draw']], diag_kind='kde')
plt.savefig("scatterplot_matrix.png")
